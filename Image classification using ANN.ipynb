# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import load_img ,img_to_array

# %%
(train_img ,train_lab),(test_img,test_lab) =cifar10.load_data()

# %%
train_img.shape
# Out:
# (50000, 32, 32, 3)

# %%
train_img[34]
# Out:
# array([[[172, 187, 130],
#         [171, 186, 130],
#         [168, 182, 126],
#         ...,
#         [158, 170, 113],
#         [156, 169, 113],
#         [147, 163, 107]],
#
#        [[169, 185, 123],
#         [168, 183, 122],
#         [168, 184, 123],
#         ...,
#         [158, 175, 114],
#         [152, 170, 110],
#         [145, 165, 107]],
#
#        [[174, 190, 126],
#         [169, 185, 122],
#         [170, 186, 123],
#         ...,
#         [157, 177, 115],
#         [149, 170, 108],
#         [146, 168, 109]],
#
#        ...,
#
#        [[150, 163, 100],
#         [157, 168, 103],
#         [162, 170, 104],
#         ...,
#         [158, 168, 108],
#         [147, 160,  99],
#         [139, 154,  90]],
#
#        [[143, 154,  89],
#         [149, 158,  90],
#         [155, 161,  96],
#         ...,
#         [148, 157,  99],
#         [143, 153,  92],
#         [140, 153,  88]],
#
#        [[148, 158,  93],
#         [146, 155,  89],
#         [149, 157,  92],
#         ...,
#         [137, 143,  86],
#         [134, 139,  80],
#         [136, 143,  82]]], dtype=uint8)

# %%
train_lab[34]
# Out:
# array([4], dtype=uint8)

# %%
plt.figure(figsize=(3,3))
plt.imshow(train_img[34])
plt.show()

# %%
classes =["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
for i in range(5):
    ind = np.random.randint(50000)
    plt.figure(figsize=(3,3))
    plt.imshow(train_img[ind])
    plt.title(classes[train_lab[ind][0]])
    plt.show()

# %%
train_img.min()
# Out:
# np.uint8(0)

# %%
train_img.max()
# Out:
# np.uint8(255)

# %%
train_img[34]/255
# Out:
# array([[[0.6745098 , 0.73333333, 0.50980392],
#         [0.67058824, 0.72941176, 0.50980392],
#         [0.65882353, 0.71372549, 0.49411765],
#         ...,
#         [0.61960784, 0.66666667, 0.44313725],
#         [0.61176471, 0.6627451 , 0.44313725],
#         [0.57647059, 0.63921569, 0.41960784]],
#
#        [[0.6627451 , 0.7254902 , 0.48235294],
#         [0.65882353, 0.71764706, 0.47843137],
#         [0.65882353, 0.72156863, 0.48235294],
#         ...,
#         [0.61960784, 0.68627451, 0.44705882],
#         [0.59607843, 0.66666667, 0.43137255],
#         [0.56862745, 0.64705882, 0.41960784]],
#
#        [[0.68235294, 0.74509804, 0.49411765],
#         [0.6627451 , 0.7254902 , 0.47843137],
#         [0.66666667, 0.72941176, 0.48235294],
#         ...,
#         [0.61568627, 0.69411765, 0.45098039],
#         [0.58431373, 0.66666667, 0.42352941],
#         [0.57254902, 0.65882353, 0.42745098]],
#
#        ...,
#
#        [[0.58823529, 0.63921569, 0.39215686],
#         [0.61568627, 0.65882353, 0.40392157],
#         [0.63529412, 0.66666667, 0.40784314],
#         ...,
#         [0.61960784, 0.65882353, 0.42352941],
#         [0.57647059, 0.62745098, 0.38823529],
#         [0.54509804, 0.60392157, 0.35294118]],
#
#        [[0.56078431, 0.60392157, 0.34901961],
#         [0.58431373, 0.61960784, 0.35294118],
#         [0.60784314, 0.63137255, 0.37647059],
#         ...,
#         [0.58039216, 0.61568627, 0.38823529],
#         [0.56078431, 0.6       , 0.36078431],
#         [0.54901961, 0.6       , 0.34509804]],
#
#        [[0.58039216, 0.61960784, 0.36470588],
#         [0.57254902, 0.60784314, 0.34901961],
#         [0.58431373, 0.61568627, 0.36078431],
#         ...,
#         [0.5372549 , 0.56078431, 0.3372549 ],
#         [0.5254902 , 0.54509804, 0.31372549],
#         [0.53333333, 0.56078431, 0.32156863]]])

# %%
plt.figure(figsize=(3,3))
plt.imshow(train_img[34]/255)
plt.show()

# %%
train_img,test_img =train_img/255 , test_img/255

# %%
train_img[342]
# Out:
# array([[[0.16470588, 0.1254902 , 0.12941176],
#         [0.18039216, 0.14117647, 0.14509804],
#         [0.18431373, 0.14509804, 0.14901961],
#         ...,
#         [0.10196078, 0.07843137, 0.07058824],
#         [0.09411765, 0.0745098 , 0.0627451 ],
#         [0.09411765, 0.07058824, 0.05882353]],
#
#        [[0.17254902, 0.1254902 , 0.1254902 ],
#         [0.18823529, 0.14117647, 0.14117647],
#         [0.19215686, 0.14509804, 0.14509804],
#         ...,
#         [0.12156863, 0.09411765, 0.08627451],
#         [0.11764706, 0.08627451, 0.07843137],
#         [0.10980392, 0.07843137, 0.07058824]],
#
#        [[0.17254902, 0.11764706, 0.11372549],
#         [0.19215686, 0.14117647, 0.13333333],
#         [0.20392157, 0.14901961, 0.14509804],
#         ...,
#         [0.1372549 , 0.09803922, 0.09411765],
#         [0.13333333, 0.09411765, 0.09019608],
#         [0.12156863, 0.08235294, 0.07843137]],
#
#        ...,
#
#        [[0.46666667, 0.38823529, 0.36862745],
#         [0.49411765, 0.40392157, 0.38431373],
#         [0.51764706, 0.41568627, 0.39215686],
#         ...,
#         [0.40392157, 0.3254902 , 0.30196078],
#         [0.38431373, 0.30588235, 0.2745098 ],
#         [0.35294118, 0.27843137, 0.25882353]],
#
#        [[0.4627451 , 0.38431373, 0.36470588],
#         [0.48627451, 0.39607843, 0.37647059],
#         [0.52156863, 0.41960784, 0.39215686],
#         ...,
#         [0.40784314, 0.32941176, 0.30196078],
#         [0.38431373, 0.30588235, 0.27843137],
#         [0.36078431, 0.28235294, 0.2627451 ]],
#
#        [[0.44705882, 0.36862745, 0.34901961],
#         [0.47058824, 0.38431373, 0.36078431],
#         [0.50588235, 0.40784314, 0.38431373],
#         ...,
#         [0.39215686, 0.31372549, 0.28627451],
#         [0.38823529, 0.30980392, 0.28235294],
#         [0.34117647, 0.26666667, 0.24705882]]])

# %%
test_img[342]
# Out:
# array([[[0.54901961, 0.64705882, 0.76862745],
#         [0.54117647, 0.63921569, 0.75294118],
#         [0.54117647, 0.63921569, 0.75294118],
#         ...,
#         [0.52156863, 0.63921569, 0.74509804],
#         [0.52156863, 0.63921569, 0.74509804],
#         [0.52156863, 0.63921569, 0.74509804]],
#
#        [[0.55686275, 0.65490196, 0.77254902],
#         [0.54901961, 0.64705882, 0.76470588],
#         [0.55294118, 0.65098039, 0.76862745],
#         ...,
#         [0.5254902 , 0.64313725, 0.75294118],
#         [0.5254902 , 0.64313725, 0.75294118],
#         [0.5254902 , 0.64313725, 0.75294118]],
#
#        [[0.55686275, 0.65490196, 0.77254902],
#         [0.55294118, 0.65098039, 0.76470588],
#         [0.55294118, 0.65098039, 0.76862745],
#         ...,
#         [0.52156863, 0.64313725, 0.75294118],
#         [0.5254902 , 0.64313725, 0.75294118],
#         [0.52156863, 0.64313725, 0.75294118]],
#
#        ...,
#
#        [[0.56078431, 0.65882353, 0.78039216],
#         [0.55686275, 0.65490196, 0.77254902],
#         [0.55686275, 0.65490196, 0.77254902],
#         ...,
#         [0.5372549 , 0.64313725, 0.76078431],
#         [0.52941176, 0.63529412, 0.75294118],
#         [0.52941176, 0.63529412, 0.75294118]],
#
#        [[0.55686275, 0.65882353, 0.78039216],
#         [0.55294118, 0.65098039, 0.77254902],
#         [0.55686275, 0.65490196, 0.77254902],
#         ...,
#         [0.5372549 , 0.64313725, 0.76078431],
#         [0.52941176, 0.63529412, 0.75294118],
#         [0.52941176, 0.63529412, 0.75294118]],
#
#        [[0.55294118, 0.65098039, 0.77254902],
#         [0.54901961, 0.64313725, 0.76078431],
#         [0.54901961, 0.64705882, 0.76078431],
#         ...,
#         [0.53333333, 0.63529412, 0.75294118],
#         [0.5254902 , 0.63137255, 0.74901961],
#         [0.5254902 , 0.63137255, 0.74509804]]])

# %%
model = Sequential([
    Flatten(input_shape =(32,32,3)),
    Dense(1000,activation="relu"),
    Dense(750,activation="relu"),
    Dense(500,activation="relu"),
    Dense(300,activation="relu"),
    Dense(200,activation="relu"),
    Dense(500,activation="relu"),
    Dense(750,activation="relu"),
    Dense(10,activation="softmax")
])
# Out:
# C:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])

# %%
model.fit(train_img ,train_lab,epochs=30,batch_size=32,validation_data=(test_img ,test_lab))
# Out:
# Epoch 1/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 70s 43ms/step - accuracy: 0.1976 - loss: 2.0839 - val_accuracy: 0.2665 - val_loss: 1.8964
# Epoch 2/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 70s 45ms/step - accuracy: 0.3088 - loss: 1.8408 - val_accuracy: 0.3246 - val_loss: 1.8151
# Epoch 3/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 77s 49ms/step - accuracy: 0.3547 - loss: 1.7561 - val_accuracy: 0.3910 - val_loss: 1.6812
# Epoch 4/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 77s 50ms/step - accuracy: 0.3904 - loss: 1.6753 - val_accuracy: 0.3996 - val_loss: 1.6589
# Epoch 5/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 77s 50ms/step - accuracy: 0.4055 - loss: 1.6415 - val_accuracy: 0.4084 - val_loss: 1.6307
# Epoch 6/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 80s 51ms/step - accuracy: 0.4161 - loss: 1.6083 - val_accuracy: 0.4332 - val_loss: 1.5758
# Epoch 7/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 83s 53ms/step - accuracy: 0.4329 - loss: 1.5737 - val_accuracy: 0.4342 - val_loss: 1.5798
# Epoch 8/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 52ms/step - accuracy: 0.4395 - loss: 1.5542 - val_accuracy: 0.4249 - val_loss: 1.6386
# Epoch 9/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 80s 51ms/step - accuracy: 0.4499 - loss: 1.5276 - val_accuracy: 0.4482 - val_loss: 1.5420
# Epoch 10/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 77s 49ms/step - accuracy: 0.4568 - loss: 1.5042 - val_accuracy: 0.4513 - val_loss: 1.5415
# Epoch 11/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 77s 49ms/step - accuracy: 0.4695 - loss: 1.4791 - val_accuracy: 0.4689 - val_loss: 1.5054
# Epoch 12/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 79s 50ms/step - accuracy: 0.4780 - loss: 1.4401 - val_accuracy: 0.4568 - val_loss: 1.5404
# Epoch 13/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 78s 50ms/step - accuracy: 0.4799 - loss: 1.4404 - val_accuracy: 0.4501 - val_loss: 1.5453
# Epoch 14/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 78s 50ms/step - accuracy: 0.4845 - loss: 1.4279 - val_accuracy: 0.4739 - val_loss: 1.5058
# Epoch 15/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 80s 51ms/step - accuracy: 0.4932 - loss: 1.4013 - val_accuracy: 0.4650 - val_loss: 1.5311
# Epoch 16/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 79s 50ms/step - accuracy: 0.5004 - loss: 1.3934 - val_accuracy: 0.4461 - val_loss: 1.5623
# Epoch 17/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 78s 50ms/step - accuracy: 0.5032 - loss: 1.3815 - val_accuracy: 0.4739 - val_loss: 1.5046
# Epoch 18/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 78s 50ms/step - accuracy: 0.5094 - loss: 1.3577 - val_accuracy: 0.4640 - val_loss: 1.5299
# Epoch 19/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 78s 50ms/step - accuracy: 0.5187 - loss: 1.3390 - val_accuracy: 0.4738 - val_loss: 1.4981
# Epoch 20/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 78s 50ms/step - accuracy: 0.5240 - loss: 1.3303 - val_accuracy: 0.4828 - val_loss: 1.4899
# Epoch 21/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 78s 50ms/step - accuracy: 0.5273 - loss: 1.3185 - val_accuracy: 0.4760 - val_loss: 1.5177
# Epoch 22/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 52ms/step - accuracy: 0.5310 - loss: 1.2985 - val_accuracy: 0.4697 - val_loss: 1.5414
# Epoch 23/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 52ms/step - accuracy: 0.5435 - loss: 1.2740 - val_accuracy: 0.4763 - val_loss: 1.4954
# Epoch 24/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 83s 53ms/step - accuracy: 0.5455 - loss: 1.2690 - val_accuracy: 0.4877 - val_loss: 1.5044
# Epoch 25/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 80s 51ms/step - accuracy: 0.5518 - loss: 1.2519 - val_accuracy: 0.4824 - val_loss: 1.5024
# Epoch 26/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 52ms/step - accuracy: 0.5534 - loss: 1.2516 - val_accuracy: 0.4817 - val_loss: 1.5168
# Epoch 27/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 79s 51ms/step - accuracy: 0.5596 - loss: 1.2313 - val_accuracy: 0.4858 - val_loss: 1.5195
# Epoch 28/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 77s 49ms/step - accuracy: 0.5618 - loss: 1.2202 - val_accuracy: 0.4723 - val_loss: 1.5452
# Epoch 29/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 77s 49ms/step - accuracy: 0.5666 - loss: 1.2060 - val_accuracy: 0.4650 - val_loss: 1.5807
# Epoch 30/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 77s 49ms/step - accuracy: 0.5788 - loss: 1.1799 - val_accuracy: 0.4746 - val_loss: 1.5682

# %%
plt.figure(figsize=(12,4))
plt.plot(model.history.history["loss"],label="Training Loss")
plt.plot(model.history.history["val_loss"],label="Validation Loss")
plt.title("Loss visualization")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.plot(model.history.history["accuracy"],label="Training Accuracy")
plt.plot(model.history.history["val_accuracy"],label="Validation Accuracy")
plt.title("Accuracy visualization")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.show()

# %%
def image_predictor(img_path):
    img = load_img(img_path ,target_size=(32,32))
    img_arr = img_to_array(img)
    img_norm = img_arr /255.0
    img_flatten = np.expand_dims(img_norm ,axis=0)
    pred = model.predict(img_flatten)
    predicted_class = classes[np.argmax(pred[0])]
    return predicted_class

# %%
image_predictor("R.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step
# 'automobile'

# %%
image_predictor("R (1).jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 'ship'

# %%
image_predictor("Horse.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 'horse'

# %%
image_predictor("truck.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 'automobile'
