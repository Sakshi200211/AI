# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array
from tensorflow.keras.optimizers import Adam

# %%
train_dir = r'D:\Data Science notes\AI\MY_data\train'
test_dir = r'D:\Data Science notes\AI\MY_data\test'

# %%
image_size = (64, 64)  
batch_size = 32

# %%
class_labels = list(train_data.class_indices.keys())

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255.0)
test_datagen = ImageDataGenerator(rescale=1.0/255.0)

# %%
train_data = train_datagen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2301 images belonging to 10 classes.

# %%
test_data = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 1025 images belonging to 10 classes.

# %%
model = Sequential([
    Flatten(input_shape=(64, 64, 3)),  # Flatten the input image
    Dense(128, activation='relu'),    # Fully connected layer
    Dense(64, activation='relu'),     # Fully connected layer
    Dense(len(train_data.class_indices), activation='softmax')  # Output layer
])
# Out:
# C:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(train_data, epochs=25, validation_data=test_data)
# Out:
# Epoch 1/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 115ms/step - accuracy: 0.4951 - loss: 1.4686 - val_accuracy: 0.3366 - val_loss: 1.9141
# Epoch 2/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.5132 - loss: 1.3973 - val_accuracy: 0.3395 - val_loss: 1.8360
# Epoch 3/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 109ms/step - accuracy: 0.5517 - loss: 1.3053 - val_accuracy: 0.3122 - val_loss: 2.0328
# Epoch 4/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 112ms/step - accuracy: 0.5432 - loss: 1.3529 - val_accuracy: 0.2888 - val_loss: 2.1071
# Epoch 5/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 110ms/step - accuracy: 0.5381 - loss: 1.2984 - val_accuracy: 0.3620 - val_loss: 1.9413
# Epoch 6/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 112ms/step - accuracy: 0.5355 - loss: 1.2750 - val_accuracy: 0.3385 - val_loss: 2.0361
# Epoch 7/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 111ms/step - accuracy: 0.5405 - loss: 1.3089 - val_accuracy: 0.3180 - val_loss: 1.9110
# Epoch 8/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 111ms/step - accuracy: 0.6215 - loss: 1.1054 - val_accuracy: 0.3737 - val_loss: 1.9429
# Epoch 9/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 112ms/step - accuracy: 0.6203 - loss: 1.1634 - val_accuracy: 0.3083 - val_loss: 2.0508
# Epoch 10/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 113ms/step - accuracy: 0.6033 - loss: 1.1222 - val_accuracy: 0.2917 - val_loss: 2.3616
# Epoch 11/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.5869 - loss: 1.1793 - val_accuracy: 0.3756 - val_loss: 2.0752
# Epoch 12/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 112ms/step - accuracy: 0.6586 - loss: 1.0012 - val_accuracy: 0.3249 - val_loss: 2.1064
# Epoch 13/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.6510 - loss: 1.0355 - val_accuracy: 0.3180 - val_loss: 2.2688
# Epoch 14/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 112ms/step - accuracy: 0.6720 - loss: 0.9848 - val_accuracy: 0.3102 - val_loss: 2.1163
# Epoch 15/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 111ms/step - accuracy: 0.6397 - loss: 1.0267 - val_accuracy: 0.3298 - val_loss: 2.2935
# Epoch 16/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 110ms/step - accuracy: 0.6661 - loss: 0.9556 - val_accuracy: 0.3639 - val_loss: 2.0654
# Epoch 17/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.6811 - loss: 0.9210 - val_accuracy: 0.4020 - val_loss: 2.0647
# Epoch 18/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 9s 120ms/step - accuracy: 0.7582 - loss: 0.7587 - val_accuracy: 0.3932 - val_loss: 2.0848
# Epoch 19/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 116ms/step - accuracy: 0.7539 - loss: 0.7615 - val_accuracy: 0.3815 - val_loss: 2.2256
# Epoch 20/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 110ms/step - accuracy: 0.7350 - loss: 0.7901 - val_accuracy: 0.3561 - val_loss: 2.2882
# Epoch 21/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 112ms/step - accuracy: 0.7520 - loss: 0.7579 - val_accuracy: 0.3620 - val_loss: 2.2736
# Epoch 22/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 112ms/step - accuracy: 0.6683 - loss: 0.9222 - val_accuracy: 0.3561 - val_loss: 2.3099
# Epoch 23/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 111ms/step - accuracy: 0.7610 - loss: 0.7234 - val_accuracy: 0.3600 - val_loss: 2.2245
# Epoch 24/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 111ms/step - accuracy: 0.8108 - loss: 0.6138 - val_accuracy: 0.3844 - val_loss: 2.3747
# Epoch 25/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 111ms/step - accuracy: 0.7994 - loss: 0.6102 - val_accuracy: 0.3180 - val_loss: 2.6273

# %%
plt.figure(figsize=(12,4))
plt.plot(model.history.history["loss"],label="Training Loss")
plt.plot(model.history.history["val_loss"],label="Validation Loss")
plt.title("Loss visualization")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.plot(model.history.history["accuracy"],label="Training Accuracy")
plt.plot(model.history.history["val_accuracy"],label="Validation Accuracy")
plt.title("Accuracy visualization")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.show()

# %%
def predict_image(image_path):
    img = load_img(image_path, target_size=(64, 64))  
    img_array = img_to_array(img) / 255.0 
    img_array = np.expand_dims(img_array, axis=0)  
    predictions = model.predict(img_array)
    predicted_class = class_labels[np.argmax(predictions)]
    
    return predicted_class

# %%
predict_image("41.jpeg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 'Apple'

# %%
predict_image("66.jpeg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 'pinenapple'

# %%
predict_image(r"D:\Data Science notes\AI\predict\2.jpeg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 'avocado'

# %%
predict_image(r"D:\Data Science notes\AI\predict\f0.jpeg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 'Apple'

# %%
predict_image(r"D:\Data Science notes\AI\predict\img_141.jpeg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 'avocado'

# %%
predict_image(r"D:\Data Science notes\AI\predict\img_191.jpeg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 'Banana'

# %%
predict_image(r"D:\Data Science notes\AI\predict\img_341.jpeg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 'mango'
